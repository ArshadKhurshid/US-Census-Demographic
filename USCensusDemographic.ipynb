# %% [markdown]
# # US Census Demographic

# %%
# Import library 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Ingestion

# %% [markdown]
# ### Data import from csv

# %%
# Import csv file to pandas dataframe

census_data = pd.read_csv('acs2015_census_tract_data.csv')
county_census_data = pd.read_csv('acs2015_county_data.csv')

# %%
### Display census data

census_data.head(10)
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
# 5   1001020600  Alabama  Autauga      3851  1787   2064      13.1   72.9
# 6   1001020700  Alabama  Autauga      2761  1210   1551       3.8   74.5
# 7   1001020801  Alabama  Autauga      3187  1502   1685       1.3   84.0
# 8   1001020802  Alabama  Autauga     10915  5486   5429       1.4   89.5
# 9   1001020900  Alabama  Autauga      5668  2897   2771       0.4   85.5
#
#    Black  Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0    7.7     0.3      ...        0.5          2.3         2.1         25.0
# 1   53.3     0.0      ...        0.0          0.7         0.0         23.4
# 2   18.6     0.5      ...        0.0          0.0         2.5         19.6
# 3    3.7     1.6      ...        0.0          2.6         1.6         25.3
# 4   24.8     0.0      ...        0.0          0.6         0.9         24.8
# 5   11.9     0.0      ...        0.0          6.0         4.5         19.8
# 6   19.7     0.0      ...        0.0          0.0         0.0         20.0
# 7   10.7     3.1      ...        0.0          1.7         5.9         24.3
# 8    8.4     0.0      ...        0.0          0.0         1.3         29.4
# 9   12.1     0.0      ...        0.0          1.2         2.1         32.9
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0       943         77.1        18.3           4.6         0.0           5.4
# 1       753         77.0        16.9           6.1         0.0          13.3
# 2      1373         64.1        23.6          12.3         0.0           6.2
# 3      1782         75.7        21.2           3.1         0.0          10.8
# 4      5037         67.1        27.6           5.3         0.0           4.2
# 5      1560         79.4        14.7           5.8         0.0          10.9
# 6      1166         82.0        14.6           3.4         0.0          11.4
# 7      1502         78.1        14.8           7.1         0.0           8.2
# 8      4348         73.3        22.1           4.6         0.0           8.7
# 9      2485         77.9        15.2           6.9         0.0           7.2
#
# [10 rows x 37 columns]

# %%
# Display county_census data
county_census_data.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
# 3     0.4      ...        0.6          1.5         0.7         28.8      8294
# 4     0.3      ...        0.9          0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         73.6        20.9           5.5         0.0           7.6
# 1         81.5        12.3           5.8         0.4           7.5
# 2         71.8        20.8           7.3         0.1          17.6
# 3         76.8        16.1           6.7         0.4           8.3
# 4         82.0        13.5           4.2         0.4           7.7
#
# [5 rows x 37 columns]

# %%
# Display total number of rows and columns
print ("County census data contains {} row and {} columns" .format(county_census_data.shape[0],county_census_data.shape[1]))
print ("Census data contains {} row and {} columns" .format(census_data.shape[0],census_data.shape[1]))
# Out:
# County census data contains 3220 row and 37 columns
# Census data contains 74001 row and 37 columns

# %% [markdown]
# ### List of columns

# %%
#Display listof columns
census_data.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'TotalPop', 'Men', 'Women',
#        'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
#Display listof columns
county_census_data.dtypes
# Out:
# CensusId             int64
# State               object
# County              object
# TotalPop             int64
# Men                  int64
# Women                int64
# Hispanic           float64
# White              float64
# Black              float64
# Native             float64
# Asian              float64
# Pacific            float64
# Citizen              int64
# Income             float64
# IncomeErr          float64
# IncomePerCap         int64
# IncomePerCapErr      int64
# Poverty            float64
# ChildPoverty       float64
# Professional       float64
# Service            float64
# Office             float64
# Construction       float64
# Production         float64
# Drive              float64
# Carpool            float64
# Transit            float64
# Walk               float64
# OtherTransp        float64
# WorkAtHome         float64
# MeanCommute        float64
# Employed             int64
# PrivateWork        float64
# PublicWork         float64
# SelfEmployed       float64
# FamilyWork         float64
# Unemployment       float64
# dtype: object

# %%
# Describe columns county_census_data
county_census_data.describe()
# Out:
#            CensusId      TotalPop           Men         Women     Hispanic  \
# count   3220.000000  3.220000e+03  3.220000e+03  3.220000e+03  3220.000000
# mean   31393.605280  9.940935e+04  4.889694e+04  5.051241e+04    11.011522
# std    16292.078954  3.193055e+05  1.566813e+05  1.626620e+05    19.241380
# min     1001.000000  8.500000e+01  4.200000e+01  4.300000e+01     0.000000
# 25%    19032.500000  1.121800e+04  5.637250e+03  5.572000e+03     1.900000
# 50%    30024.000000  2.603500e+04  1.293200e+04  1.305700e+04     3.900000
# 75%    46105.500000  6.643050e+04  3.299275e+04  3.348750e+04     9.825000
# max    72153.000000  1.003839e+07  4.945351e+06  5.093037e+06    99.900000
#
#              White        Black       Native        Asian      Pacific  \
# count  3220.000000  3220.000000  3220.000000  3220.000000  3220.000000
# mean     75.428789     8.665497     1.723509     1.229068     0.082733
# std      22.932890    14.279122     7.253115     2.633079     0.734931
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      64.100000     0.500000     0.100000     0.200000     0.000000
# 50%      84.100000     1.900000     0.300000     0.500000     0.000000
# 75%      93.200000     9.600000     0.600000     1.200000     0.000000
# max      99.800000    85.900000    92.100000    41.600000    35.300000
#
#            ...              Walk  OtherTransp   WorkAtHome  MeanCommute  \
# count      ...       3220.000000  3220.000000  3220.000000  3220.000000
# mean       ...          3.323509     1.612733     4.631770    23.278758
# std        ...          3.756096     1.670988     3.178772     5.600466
# min        ...          0.000000     0.000000     0.000000     4.900000
# 25%        ...          1.400000     0.900000     2.700000    19.500000
# 50%        ...          2.400000     1.300000     3.900000    23.000000
# 75%        ...          4.000000     1.900000     5.600000    26.800000
# max        ...         71.200000    39.100000    37.200000    44.000000
#
#            Employed  PrivateWork   PublicWork  SelfEmployed   FamilyWork  \
# count  3.220000e+03  3220.000000  3220.000000   3220.000000  3220.000000
# mean   4.559352e+04    74.219348    17.560870      7.931801     0.288106
# std    1.496995e+05     7.863188     6.510354      3.914974     0.455137
# min    6.200000e+01    25.000000     5.800000      0.000000     0.000000
# 25%    4.550750e+03    70.500000    13.100000      5.400000     0.100000
# 50%    1.050800e+04    75.700000    16.200000      6.900000     0.200000
# 75%    2.863275e+04    79.700000    20.500000      9.400000     0.300000
# max    4.635465e+06    88.300000    66.200000     36.600000     9.800000
#
#        Unemployment
# count   3220.000000
# mean       8.094441
# std        4.096114
# min        0.000000
# 25%        5.500000
# 50%        7.600000
# 75%        9.900000
# max       36.500000
#
# [8 rows x 35 columns]

# %%
# Describe columns tract_census_data
census_data.describe()
# Out:
#         CensusTract      TotalPop           Men         Women      Hispanic  \
# count  7.400100e+04  74001.000000  74001.000000  74001.000000  73311.000000
# mean   2.839113e+10   4325.591465   2127.648816   2197.942649     16.862810
# std    1.647593e+10   2129.306903   1072.332031   1095.730931     22.940695
# min    1.001020e+09      0.000000      0.000000      0.000000      0.000000
# 50%        ...           1.400000      1.100000      3.500000     25.000000
# 75%        ...           3.500000      2.500000      5.900000     29.800000
# max        ...         100.000000    100.000000    100.000000     80.000000
#
#            Employed   PrivateWork    PublicWork  SelfEmployed    FamilyWork  \
# count  74001.000000  73194.000000  73194.000000  73194.000000  73194.000000
# mean    1983.907366     78.975238     14.621566      6.233814      0.169772
# std     1073.429808      8.345758      7.535786      4.042990      0.458227
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1249.000000     74.600000      9.600000      3.500000      0.000000
# 50%     1846.000000     80.100000     13.400000      5.500000      0.000000
# 75%     2553.000000     84.600000     18.200000      8.100000      0.000000
# max    24075.000000    100.000000    100.000000    100.000000     26.500000
#
#        Unemployment
# count  73199.000000
# mean       9.028663
# std        5.955441
# min        0.000000
# 25%        5.100000
# 50%        7.700000
# 75%       11.400000
# max      100.000000
#
# [8 rows x 34 columns]

# %%
# Import train test split and Decision tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

#Define calculation for regrssor score
def regressor_score(regressor, new_data,new_data_y, label):
    
    X_train, X_test, y_train, y_test = train_test_split(new_data,new_data_y, test_size = 0.25, random_state = 0)
    
    regressor.fit(X_train,y_train)

# TODO: Report the score of the prediction using the testing set
    score = regressor.score(X_test, y_test)
    print ('Label: {} # Score is:{}' .format(label,score))

# %%
data=pd.DataFrame.copy(census_data)
data.dropna(inplace=True)
regressor = DecisionTreeRegressor()

label_list = ['TotalPop', 'Men', 'Women',
       'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen', 'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
       'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
       'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment']

for label in label_list:
    new_data = pd.DataFrame.copy(data)
    new_data_y = new_data[label]    
    new_data.drop(label, axis=1, inplace=True)

    regressor_score(regressor, new_data,new_data_y, label)
# Out:
# Label: TotalPop # Score is:0.998921067947219
# Label: Men # Score is:0.9962652668014198
# Label: Women # Score is:0.9958054644034163
# Label: Hispanic # Score is:0.9740002616200794
# Label: White # Score is:0.9829801242802934
# Label: Black # Score is:0.9714011442250838
# Label: Native # Score is:0.2469485666226218
# Label: Asian # Score is:0.7997676692307789
# Label: Pacific # Score is:-0.4558409986544205
# Label: Citizen # Score is:0.920620916092001
# Label: Income # Score is:0.7528413734866233
# Label: IncomeErr # Score is:-0.05124072459429385
# Label: IncomePerCap # Score is:0.8815440980301752
# Label: IncomePerCapErr # Score is:0.5479474969343117
# Label: Poverty # Score is:0.8768980488359921
# Label: ChildPoverty # Score is:0.7168840260010756
# Label: Professional # Score is:0.9398734545270268
# Label: Service # Score is:0.8524610445735625
# Label: Office # Score is:0.8102612788073359
# Label: Construction # Score is:0.7748578675267477
# Label: Production # Score is:0.8945173910943481
# Label: Drive # Score is:0.9709453050508543
# Label: Carpool # Score is:0.7738451926746518
# Label: Transit # Score is:0.9401859514467305
# Label: Walk # Score is:0.7618777092272391
# Label: OtherTransp # Score is:0.3032774701091935
# Label: WorkAtHome # Score is:0.3379173769754601
# Label: MeanCommute # Score is:0.01531187855260352
# Label: Employed # Score is:0.8757765922526988
# Label: PrivateWork # Score is:0.9958158472532346
# Label: PublicWork # Score is:0.994910848006957
# Label: SelfEmployed # Score is:0.9730226594461634
# Label: FamilyWork # Score is:-0.2529392020517587
# Label: Unemployment # Score is:0.15239668877635282

# %%
#Produce a scatter matrix for data
pd.plotting.scatter_matrix(data, alpha = 0.3, figsize = (14,8), diagonal = 'kde')
